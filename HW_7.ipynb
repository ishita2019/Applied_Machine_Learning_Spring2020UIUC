# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from scipy.misc import imread, imsave
from mnist import MNIST

# %%
mndata = MNIST('./MNIST_DataSet')
training_images, training_labels = mndata.load_training()

# %%
 # reshape first image(1 D vector) to 2D dimension image
def reshape_plot(img):
    result_img = np.reshape(img, (28, 28))
    #plt.subplot(111)
    #plt.imshow(result_img, cmap=plt.get_cmap('gray'))
    #plt.show()
    return result_img

# %%
#binarize each image with threshold of 127 
def binarize(img):
    max_indices = img >= 127
    min_indices= img < 127
    img[max_indices] = 1
    img[min_indices] = -1
    
#   threshold = 127
#  # make all pixels < threshold black
#   binarized = 1.0 * (img >= threshold) 
    #plt.imshow(img,cmap=plt.get_cmap('gray'), vmin=-1)
   # plt.show()
    return img

# %%
# def random_flipping(img):
#     plt.imshow(img,cmap=plt.get_cmap('gray'), vmin=-1)
#     plt.show()
#     flattened_img= img.flatten()
#     index_1=random.choice(list(enumerate(flattened_img)))
#     index_2=random.choice(list(enumerate(flattened_img)))
#     #print(index_1[0],index_1[1],index_2[0],index_2[1] )
#     flattened_img[index_1[0]]= -1*flattened_img[index_1[0]]
#     flattened_img[index_2[0]]= -1*flattened_img[index_2[0]]
#     #print(flattened_img[index_1[0]],flattened_img[index_2[0]])
#     noisy_binary_img = np.reshape(flattened_img, (28, 28))
#     plt.imshow(noisy_binary_img,cmap=plt.get_cmap('gray'), vmin=-1)
#     plt.show()
    
#     return noisy_binary_img

# %%
def random_flipping(img):
    plt.imshow(img,cmap=plt.get_cmap('gray'), vmin=-1)
    plt.show()
    flattened_img= binarized_img.flatten()
    m= int(flattened_img.size*2/100)
    idx= np.random.choice(flattened_img.size, m, replace=False)
    flattened_img[idx]=-flattened_img[idx]
    noisy_binary_img = np.reshape(flattened_img, (28, 28))
    plt.imshow(noisy_binary_img,cmap=plt.get_cmap('gray'), vmin=-1)
    plt.show()
    
    return noisy_binary_img

# %%
training_set, label_set = training_images[0:500], training_labels[0:500]
pixels_training_set = np.array(training_set, dtype='uint8')
print(pixels_training_set.shape)
# Out:
# (500, 784)

# %%
pixels_training_lbl =np.array(label_set, dtype='uint8')
print(pixels_training_set.shape)
# Out:
# (500, 784)

# %%
noisy_images_array = np.array([])
for i in range (0,499):
    img_arr, img_label = training_images[i], training_labels[i]
    img=reshape_plot(img_arr)
    binarized_img=binarize(img)
    noisy_img= random_flipping(binarized_img)
    noisy_images_array=np.append(noisy_images_array, noisy_img)
